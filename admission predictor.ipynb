# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
sns.set(style='white')
sns.set(style='whitegrid',color_codes=True)

# %%
data=pd.read_csv("C:\Windows\Lenovo\\Admission_Predict.csv")

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance
# 0         1    0.92
# 1         1    0.76
# 2         1    0.72
# 3         1    0.80
# 4         0    0.65

# %%
data.shape
# Out:
# (400, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
# GRE Score            400 non-null int64
# TOEFL Score          400 non-null int64
# University Rating    400 non-null int64
# SOP                  400 non-null float64
# LOR                  400 non-null float64
# CGPA                 400 non-null float64
# Research             400 non-null int64
# Chance of Admit      400 non-null float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %%
data.drop('Serial No.',axis=1,inplace=True)

# %%
data['Chance']
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
# 5      0.90
# 6      0.75
# 7      0.68
# 8      0.50
# 9      0.45
# 10     0.52
# 11     0.84
# 12     0.78
# 13     0.62
# 14     0.61
# 15     0.54
# 16     0.66
# 17     0.65
# 18     0.63
# 19     0.62
# 20     0.64
# 21     0.70
# 22     0.94
# 23     0.95
# 24     0.97
# 25     0.94
# 26     0.76
# 27     0.44
# 28     0.46
# 29     0.54
#        ...
# 370    0.72
# 371    0.89
# 372    0.95
# 373    0.79
# 374    0.39
# 375    0.38
# 376    0.34
# 377    0.47
# 378    0.56
# 379    0.71
# 380    0.78
# 381    0.73
# 382    0.82
# 383    0.62
# 384    0.96
# 385    0.96
# 386    0.46
# 387    0.53
# 388    0.49
# 389    0.76
# 390    0.64
# 391    0.71
# 392    0.84
# 393    0.77
# 394    0.89
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance, Length: 400, dtype: float64

# %% [markdown]
# lets plot a heatmap to check the correlation of<br> diffrent factors with respect to chances

# %%
fig ,ax=plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,cmap='Blues')

# %% [markdown]
# clearly here GRE score,TOEFL and CGPA has the most weightage but lets see check the relationship between all the factors

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.distplot(data['CGPA'])
plt.title('CGPA Distribution of Applicants')

plt.subplot(1,2,2)
sns.regplot(data['CGPA'], data['Chance'])
plt.title('CGPA vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'CGPA vs Chance of Admit')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.distplot(data['TOEFL Score'])
plt.title('TOEFL Distribution of Applicants')

plt.subplot(1,2,2)
sns.regplot(data['TOEFL Score'], data['Chance'])
plt.title('TOEFL vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'TOEFL vs Chance of Admit')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.distplot(data['University Rating'])
plt.title('university rating Distribution of Applicants')

plt.subplot(1,2,2)
sns.regplot(data['University Rating'], data['Chance'])
plt.title('University Rating vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'University Rating vs Chance of Admit')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.distplot(data['Research'])
plt.title('Research of Applicants')

plt.subplot(1,2,2)
sns.regplot(data['Research'], data['Chance'])
plt.title('Research vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'Research vs Chance of Admit')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.distplot(data['SOP'])
plt.title('SOP Distribution of Applicants')

plt.subplot(1,2,2)
sns.regplot(data['SOP'], data['Chance'])
plt.title('SOP vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'SOP vs Chance of Admit')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.distplot(data['LOR '])
plt.title('LOR Distribution of Applicants')

plt.subplot(1,2,2)
sns.regplot(data['LOR '], data['Chance'])
plt.title('LOR vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'LOR vs Chance of Admit')

# %% [markdown]
# lets check how many people have research experince and how many people come<br> from tier 1,2,3 universities

# %%
fig, ax1 = plt.subplots(figsize=(8,6))
sns.countplot(data['University Rating'])
plt.title('University Rating')
plt.ylabel('Number of Applicants')

fig, ax = plt.subplots(figsize=(8,6))
sns.countplot(data['Research'])
plt.title('Research Experience')
plt.ylabel('Number of Applicants')
ax.set_xticklabels(['No Research Experience', 'Has Research Experience'])
# Out:
# [Text(0, 0, 'No Research Experience'), Text(0, 0, 'Has Research Experience')]

# %% [markdown]
# lets now prepare the data for analysis

# %%
targets = data['Chance']
features = data.drop(columns = {'Chance'})

X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# now lets impliment 3 types of models and see which one is best

# %% [markdown]
# linear Regression

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
y_predict = linreg.predict(X_test)
linreg_score = (linreg.score(X_test, y_test))*100
linreg_score
# Out:
# 81.66122714445567

# %% [markdown]
# Decision Trees

# %%
dec_tree = DecisionTreeRegressor(random_state=0, max_depth=6)
dec_tree.fit(X_train, y_train)
y_predict = dec_tree.predict(X_test)
dec_tree_score = (dec_tree.score(X_test, y_test))*100
dec_tree_score
# Out:
# 74.93918072287038

# %% [markdown]
# Random Forests

# %%
forest = RandomForestRegressor(n_estimators=110,max_depth=6,random_state=0)
forest.fit(X_train, y_train)
y_predict = forest.predict(X_test)
forest_score = (forest.score(X_test, y_test))*100
forest_score
# Out:
# 82.7237188855276

# %%
Methods = ['Linear Regression', 'Decision Trees', 'Random Forests']
Scores = np.array([linreg_score, dec_tree_score, forest_score])

fig, ax = plt.subplots(figsize=(10,12))
sns.barplot(Methods, Scores)
plt.title('Algorithm Prediction Accuracies')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# clearly RandomForest is the most accurate model
